# %%
from tqdm import tqdm
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import nltk
nltk.download('cess_cat')
# Out:
# [nltk_data] Downloading package cess_cat to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cess_cat.zip.
# True

# %%
from nltk.corpus import cess_cat as corpus

words = []
words_to_remove = ['*0*', '-Fpa-', '-Fpt-']
#for s in tqdm(corpus.sents()[:1000]): # debug or quickly train the network
for s in tqdm(corpus.sents()):
    new_s = ['<s>'] + s[:-1] + ['</s>']
    new_s = [w for w in new_s if w not in words_to_remove]
    words.extend(new_s)
# Out:
# 100%|██████████| 17104/17104 [00:13<00:00, 1230.79it/s]

# %%
from torch.utils.data import Dataset, DataLoader

class FixedWindow(Dataset):
    def __init__(self, words, length_window):
        self.length_window = length_window
        vocabulary = list(set(words))
        self.word2id = {w: i for i, w in enumerate(vocabulary)}
        self.id2word = {i: w for i, w in enumerate(vocabulary)}
        self.vocabulary_size = len(vocabulary)
        self.ids = [self.word2id[w] for w in words]

    def __len__(self):
        return len(self.ids) - self.length_window

    def __getitem__(self, idx):
        first_ids = self.ids[idx : idx+self.length_window-1]
        last_id = self.ids[idx+self.length_window-1]
        return torch.tensor(first_ids), torch.tensor(last_id)


length_window = 5
dataset = FixedWindow(words, length_window)

x, y = dataset.__getitem__(10)
#print('x = {}, y = {}'.format(x, y))

batch_size = 1000 # 5 to debug
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True) # shuffle=False to debug

if True:
    for nbatch, (X, y) in enumerate(dataloader):
        print('batch {}'.format(nbatch))
        print('X = {}'.format(X))
        print('y = {}'.format(y))
        for x,z in zip(X.numpy(), y.numpy()):
            print([dataset.id2word[w] for w in x], end=' ')
            print(dataset.id2word[z])
        if nbatch==3:
            break
# Out:
# batch 0
# X = tensor([[18263, 37255, 32300,  4300],
#         [29100, 21007, 17871, 27653],
#         [30793, 35077, 30399, 28282],
#         ...,
#         [ 4300, 12803,  2917,  8856],
#         [35801, 27653, 23583, 38578],
#         [ 4300, 22223, 37244, 21007]])
# y = tensor([11592, 23583, 32300, 26225, 30049, 25849, 22419, 32300,  5147, 31450,
#         36566,  2360, 11592, 38765, 32300, 32300,  2964, 10251, 23452, 21573,
#         25849, 23583, 38925, 27653, 33125, 21007,   770, 25849,  4300,  5147,
#         24943, 21007, 21007, 21007,  1802,  7152,  1179,  7912, 23583,  9884,
#         27653, 30801, 12495, 10251, 21808, 30323, 11568, 25237, 25849, 23747,
#         26421, 21663,  2636, 17028, 17355, 23583, 17473, 23583, 30821, 16052,
#         12456, 21502,  4619,   770, 21808, 32300,  6577, 16385, 19056, 27653,
#         27108, 25983, 30926, 32066, 32556, 29846, 13290, 30021, 18274, 38404,
#         23583, 22937,  7300, 11102, 35918,  2917, 27653, 29405, 11028, 16369,
#          1482, 24781, 25849, 16052,   770, 21122, 28017, 29846, 33125, 30821,
#         16374, 33125, 21150,  5147, 33125, 29067,  1802, 33700, 10587,  4405,
#         14743, 14276, 22987, 27653,  9096,  8066, 27653, 18492, 33125, 36021,
#          8339, 21007, 18185, 30235, 21007,   603, 15812, 32481, 21007,  4723,
#          5147, 36252, 19957, 16052, 30893, 12380, 21663, 32300,  7282,  2917,
#          2493, 23545, 37260,   857, 30821, 37466,  2674,   770, 32300, 38594,
#          3896, 31952, 23583, 33125, 18022, 17815, 15755,   857, 30821,  2670,
#         30021,   857, 33673,  2003,  2643, 27653,  5557,  6540, 23962,   308,
#         30564,  8775, 17815, 39395, 18185, 14355, 34950, 38790, 32300, 21567,
#          4240,  1856,   857, 25849,  2838,  9289, 26771,  1448, 39634,   226,
#          1431, 32300, 36021, 20612, 29541,  2964, 39514, 27653, 24951, 10019,
#         30021, 25190, 21150,   654, 24889, 25849, 29846,   857, 30821, 36958,
#         29846, 29148, 32300, 34848,   968, 21007, 10840, 38290,  2784, 13298,
#         38224, 32300, 25849, 22030, 21944, 17352, 31575, 19410, 39139, 30821,
#          9514, 24201, 28447, 19056,  6318, 23583, 17091, 10251,    52, 25312,
#         11568, 21007, 22677, 36021, 30021, 33125, 33482, 21007, 21150,  4300,
#         23258, 32300, 12050, 12290,  7219,  2964,  8236, 19853, 16553, 30814])
# ['al', 'Prelitoral', ',', 'i'] entre
# ['veterans', 'de', 'Televisió_de_Catalunya', '</s>'] <s>
# ['afectat', 'segons', 'algunes', 'estimacions'] ,
# ['el', 'famós', 'i', 'massiu'] tràfic
# ['Así_se_hizo_..._la_ciudad_de_las_hormigas', '</s>', '<s>', 'El'] realitzador
# ['<s>', 'Pujol', 'ha', 'lamentat'] que
# ["l'", 'estrena', 'de', 'la'] minisèrie
# ['passarà', 'per', 'la', 'Prioral_de_Sant_Pere'] ,
# ['pallassos', 'procedents', 'de', 'tot'] el
# ['que', 'la_seva', 'situació', 'és'] especial
# ['per', 'a', 'que', 'portin'] una
# ['impostos', 'i', 'minoritaris', ','] 435.044
# ['només', 'se', "'n", 'consumeix'] entre
# ['va', 'cristal·litzar', 'amb', 'la'] gloriosa
# ['al', 'Parlament_de_Catalunya', ',', 'Elisenda_Forés'] ,
# ['mai', 'la', 'pressió', '"'] ,
# ['"', 'desproporcionada', '"', 'si'] es
# ['ha', 'destacat', 'les', 'col·laboracions'] amb
# ['component', 'bàsic', 'dels', 'seus'] versos
# ['diaris', 'en', 'les', 'dues'] direccions
# ['Revolució', 'dels', 'clavells', ','] que
# ['del', 'grup', 'Pam_i_Pipa', '</s>'] <s>
# ['desacord', 'entre', 'les', 'patronals'] Foment_del_Treball
# ['va', 'ser', 'adequada', '"'] </s>
# ['ambaixador', 'del', 'grup', 'Fiat'] "
# ['està', 'formada', 'per', 'integrants'] de
# ['</s>', '<s>', 'Pel_que_fa_al', 'redactat'] del
# ['en', 'la', 'qual', 'manifesta'] que
# ['al', 'seu', 'lloc', '"'] i
# ['any', 'passat', ',', 'davant'] el
# ['cua', 'per', 'adquirir', 'les'] localitats
# ['socialistes', 'incrementant', 'la_seva', 'estimació'] de
# ['</s>', '<s>', 'El', 'president'] de
# ['EUA', 'durant', 'els', 'anys'] de
# ['12', 'anys', 'circulin', 'com_a'] '
# ['també', 'és', 'una', 'altra'] novetat
# ['setmana', ',', 'davant', 'la'] baixa
# [',', 'i', 'és', 'la'] companyia
# ['de', "l'", 'ajuntament', '</s>'] <s>
# ['més', 'plausible', 'però', 'ha'] fet
# ['la', 'localitat', "d'", 'Olesa_de_Montserrat'] </s>
# ["d'", 'arquitectònic', 'i', 'un'] altre
# ['línia', 'de', "l'", 'anomenada'] música
# ['Tot_i', 'ser', 'una', 'comarca'] amb
# ['ahir', 'a', 'la', 'matinada'] van
# [',', 'fora', 'del', 'tòpic'] nadalenc
# ['retallada', 'de', 'plantilla', 'ha'] estat
# ['del', 'PSC', '</s>', '<s>'] Allà
# ['Full_Parroquial_de_la_Diòcesi_de_Girona', ',', "l'", 'Associació_Germans_sense_Fronteres'] que
# ['fent', 'angle', 'en', 'plena'] sessió
# ['el', 'millor', 'incentiu', ','] afirma
# ['estilaven', '</s>', '<s>', 'Tot'] va
# ['assignatura', 'pendent', '</s>', '<s>'] Són
# ['impacte', 'ambiental', "s'", 'hi'] afegirà
# ['que', 'va', 'patir', 'un'] cop
# ['potencial', "d'", 'Ociempordà', '</s>'] <s>
# ['Espanya', '</s>', '<s>', 'Els'] tres
# ['de', 'les', 'jornades', '</s>'] <s>
# ['Dolors_Sistac', "amb_motiu_d'", 'haver', 'rebut'] la
# ['de', 'Bellmunt', '</s>', '<s>'] La
# ['les', 'persones', '</s>', '<s>'] Segons
# ['de', 'nomenaments', 'tutelars', 'no'] testamentaris
# ['un', '10_%', 'i', 'un'] 13_%
# ['va', 'suposar', 'un', 'increment'] del
# ['Londonderry', ',', 'per_exemple', ','] van
# ['de', 'Mourinho', 'i', 'Hoek'] ,
# ['la', 'candidatura', 'al', 'centre'] ITER
# ['a', 'les', 'estadístiques', 'a_causa_que'] molts
# ['a', 'Osona', '</s>', '<s>'] En
# ['al', 'front', 'comú', "'"] </s>
# ['eleccions', 'catalanes', 'i', 'un'] plebiscit
# ['tot', 'el', 'món', ','] 16
# ['16_de_setembre', ',', '105', 'concerts'] repartits
# ['En', "l'", 'impuls', 'del'] desenvolupament
# ['i', 'responsable', 'de', 'salut'] laboral
# ['les', 'carreteres', "d'", 'entrada'] a
# ['paquet', "d'", 'Habanos', 'es'] vendrà
# ['parcialment', 'el', 'recurs', "d'"] un
# ['la', 'gent', '</s>', '<s>'] De_Sàrraga
# ['any', 'anterior', '</s>', '<s>'] Telefónica
# ['acordat', 'el', 'Consell_de_Ministres', '</s>'] <s>
# ['a', 'institucions', 'com', 'la'] Diputació_de_Girona
# ['Plana_Ràdio', ',', 'de', 'Santa_Bàrbara'] Montsià
# ['a', "l'", 'estació', 'superior'] sobre
# ["d'", 'entrar', 'en', 'el'] capítol
# ['<s>', 'En', 'té', 'sis'] d'
# ['els_seus', 'familiars', 'de', 'Miami'] </s>
# ['concurs', 'de', 'guió', 'de'] gènere
# ['a', 'la', 'democràcia', 'i'] ara
# ['Pladevall', 'com', "'", 'el'] corpus
# ['dels', '25', 'anys', "d'"] actuacions
# ["d'", 'agents', 'de', 'la'] Guàrdia_Civil
# ['cinc', 'Facultats', 'i', 'Escoles'] que
# ['nou', 'Trambaix', '</s>', '<s>'] La
# ['regidors', 'tenen', 'el', 'suport'] del
# ['directament', 'a', 'Madrid', ','] mentre_que
# ['de', 'manifestar', 'els_seus', 'dubtes'] en_públic
# ['Granollers', 'participen', 'aquest', 'diumenge'] a
# ['les', 'expectatives', 'espanyoles', ':'] "
# ['vaga', 'del', '14_de_desembre', ','] la
# ['societat', 'catalana', ',', 'que'] havien
# ['generositat', 'de', 'Fedrico_Luppi', ','] "
# ['ha', 'criticat', 'la', 'Generalitat'] per
# ['la', 'mateixa', 'xifra', 'que'] el
# [',', 'explica', '</s>', '<s>'] "
# ['Banesto', 'va', 'començar', 'fa'] sis
# ['Plataforma', 'ha', 'qualificat', 'de'] '
# ['rendes', 'i', 'rendiments', 'del'] capital
# ['aquesta', 'situació', ',', 'cal'] definir
# ['permeten', 'diversificar', 'el', 'sector'] agrari
# ['La_2', 'i', 'el', 'macroespai'] El_día_del_Milenio
# ['càrrec', 'en', 'un', 'acte'] solemne
# ['de', 'la', 'Rambla', ','] davant
# ['aquests', 'casos', 'als', 'tribunals'] </s>
# ['milions', 'de', 'pessetes', 'en'] exportacions
# ['aquest', 'grup', 'va', 'cometre'] crims
# ['deute', 'econòmic', 'que', 'tenien'] </s>
# ["L'", 'enllaç', 'de', 'la'] Molina
# ['la', 'prova', '</s>', '<s>'] "
# ['sol·licitaran', 'els', 'panells', 'de'] l'
# ['Els', 'Estats_Units', 'van', 'tornar'] ahir
# ['de', 'les', 'noves', 'tecnologies'] de
# ['<s>', '-', 'La_meva', 'gent'] són
# ['de', 'la', 'col·lecció', 'dels'] hereus
# ['previst', 'invertir', '3.800', 'milions'] de
# ['premiar', 'Luíso_Berdejo', 'en', 'el'] concurs
# ['tots', 'els', 'públics', ','] no
# ['i', 'que', 'ja', 'solen'] tenir
# ['punt', "d'", 'intercanvi', 'i'] de
# ['i', "l'", 'autonomia', 'del'] pacient
# ['estrangers', 'és', 'menor', ':'] el
# ['comunicat', '</s>', '<s>', "L'"] escriptor
# ['entrada', 'lliure', 'per', 'a'] tothom
# ['i', 'pulmó', '</s>', '<s>'] La
# ['representa', 'el', 'programa', 'de'] Defensa
# ['tecnologies', 'i', 'els', 'nous'] temps
# ['</s>', '<s>', 'Auger', 'sempre'] va
# ['i', 'les', 'desigualtats', 'humanes'] ,
# ['persones', 'o', 'entitats', 'que'] han
# [',', 'se', "l'", 'acusa'] d'
# ['incidents', ',', 'encara_que', 'les'] cues
# ['com', 'la', 'resta', 'del'] cos
# ['durà_a_terme', 'una', 'oposició', 'seriosa'] ,
# ['el', 'passat', 'i', 'superar'] el
# ['mesures', 'legals', '</s>', '<s>'] Els
# ['vol', 'que', 'la_seva', 'opinió'] fereixi
# ['xiulets', 'i', 'li', 'van'] dedicar
# ['Metamorphosis', "'", ',', 'organitzada'] per
# [',', 'suau', ';', 'de'] fons
# ['la', 'vegetació', 'tindrà', 'un'] paper
# ['la', 'ramaderia', 'de', 'Fumadó'] a
# ['euro', 'i', "s'", 'està'] basant
# ['sector', 'defensa', 'la', 'funció'] assessora
# ['<s>', '"', 'Jo', 'no'] demanava
# ['a', 'les', '20.15', 'hores'] a
# ['correcta', 'convivència', '</s>', '<s>'] En_conseqüència
# ['zona', '</s>', '<s>', 'Aquest'] és
# ['per', 'engegar', 'noves', 'iniciatives'] empresarials
# ['població', 'local', 'no', 'ha'] vist
# ['-se', 'amb', 'molta', 'rapidesa'] </s>
# ['</s>', '<s>', 'Que', 'tingui'] tenebres
# ['coses', 'que', ',', 'objectivament'] ,
# ['recollida', 'i', 'abocament', 'de'] purins
# ["l'", 'actuació', 'dels', 'anti-avalots'] que
# ['és', 'segur', '"', ','] diu
# ['Una', 'avioneta', 'antiincendis', 'fa'] una
# ['participar', 'activament', 'en', 'moviments'] solidaris
# ['temps', 'a', 'agafar', 'hagués'] estat
# ['jugant', 'amb', 'una', 'pilota'] ,
# ['disseny', 'de', 'les', 'ventilacions'] de
# ['agents', 'socials', ',', 'econòmics'] i
# ['professors', 'Josefina_Albert', 'i', 'José_M._Fernández'] del
# ['sud', "d'", 'Europa', ':'] el
# ['de', 'Girona', '</s>', '<s>'] Les
# ['turístiques', 'i', "d'", 'entitats'] de
# ["'", ',', 'també', 'de'] Columna_Edicions
# ['Casa_de_Juntes', 'de', 'Gernika', '</s>'] <s>
# ['que', "l'", 'estrena', 'de'] l'
# ['dirigents', 'de', 'HB', ','] "
# ['1_de_juny_del_2001', 'la', 'firma', 'comercial'] i
# ['va', 'oferir', ',', 'sobretot'] ,
# ['votar', 'en', 'aquestes', 'eleccions'] 3.339
# ['</s>', '<s>', "L'", 'Associació'] AIS
# ['que', "l'", 'homosexualitat', 'sigui'] natural
# ['en', 'estat', 'greu', ','] i
# ['lluny', 'dels', 'paràmetres', "d'"] accidentabilitat
# ['ha', "d'", 'entendre', 'com'] l'
# ['estratègia', 'respecte_a', 'la', 'derrota'] final
# ['un', 'esborrany', "d'", 'un'] programa
# ['emissores', 'municipals', 'que', 'emetran'] el
# ['esforç', 'i', "l'", 'interès'] demostrat
# ['la', 'figura', 'de', "l'"] escriptor
# ['acusació', ',', 'el', 'setembre'] de
# ['infantil', 'es', 'complementaran', 'amb'] la
# ['president', 'Jacques_Chirac', 'era', 'alcalde'] de
# ['Bidasoa', 'Mèxic', ',', 'MLSP'] Brasil
# ['ell', 'és', 'el', 'president'] d'
# ['<s>', 'Mentre_que', 'el', 'tècnic'] escocès
# ['una', 'solució', 'com_més_aviat_millor', ','] perquè
# ['</s>', '<s>', 'En', 'aquell'] moment
# ['preguntarà', 'per', 'carta', ','] es
# ['parts', ',', 'que', 'fan_referència'] a
# ['concertista', 'de', 'fama', 'europea'] </s>
# ['</s>', '<s>', 'La', 'comarca'] del
# [',', 'està', 'tant', 'o'] més
# ['hi', 'haurà', 'dos', 'dels'] artistes
# ['zones', 'concretes', 'a', 'la'] ciutat
# ['un', 'episodi', 'de', 'contaminació'] ,
# ['neu-cams', '"', ',', 'unes'] càmeres
# ['160', 'expositors', '</s>', '<s>'] La
# ['eleccions', 'municipals', 'i', 'autonòmiques'] ,
# ['amb', "'", 'Mulholland_Drive', "'"] i
# ['</s>', '<s>', 'Segons', 'Bertran'] la
# ['Govern', 'balear', 'un', '"'] esforç
# ['continguda', 'i', 'on', 'tota'] la
# ['els', 'cabells', 'de', 'punta'] al
# ['aquests', 'mètodes', 'no', 'ofereixen'] resultats
# ['començar', 'a', 'treballar', 'a'] la
# ['una', 'petició', 'de', 'dimissió'] del
# ['establir', 'la', 'LOFCA', '</s>'] <s>
# ["l'", 'Audiència_de_Girona', 'el', 'proper'] dia_17
# ['destaca', 'el', 'concert', 'que'] oferirà
# ['"', ',', 'cosa', 'que'] al
# [',', 'els', 'imports', 'màxims'] per
# ['ho', 'va', 'fer', "'"] ,
# ['relatius', 'a', 'les', 'activitats'] del
# ["d'", 'ERC', 'Xavier_Sáez', 'destapés'] l'
# ['pecats', 'i', 'per', 'la_meva'] poca
# [',', "l'", 'Hotel_Cabana', ','] a
# ['i', 'guants', 'que', "l'"] acrediten
# ['control', 'de', 'costos', 'operatius'] ,
# ['havia', 'contra', 'ell', 'per'] la
# ['del', 'seu', 'càrrec', 'i'] creuen
# ["s'", 'han', 'liquidat', 'en'] una
# ['el', 'representant', 'de', 'les'] emissores
# ['Madrid', 'i', 'es', 'van'] entrevistar
# ['col·lector', 'del', 'carrer', 'de'] Maria_Auxiliadora
# ['eleccions', 'basques', 'del', '13_de_maig'] ,
# ['aquest', 'migdia', 'a', 'la'] Fundació_Autor
# ['convencional', 'tirant', 'a', 'prehistòrica'] van
# ['que', 'el', 'text', 'el'] tenia
# ['de', 'diferents', 'autors', 'amb'] textos
# ['celebrar', 'el', 'judici', 'previst'] per
# ['tindrà', '"', 'èxit', 'en'] aquest
# ['en', 'tot', 'moment', 'com_a_mínim'] un
# ['desaparegut', 'músic', ':', 'Elton_John'] Imagine
# [',', 'el_seu', 'col·lega', 'de'] l'
# [':', 'Arts', ',', 'Cientificotècnica'] ,
# ['</s>', '<s>', '1996', '</s>'] <s>
# ['Administració_de_la_Generalitat', ',', 'amb', "l'"] objectiu
# ['una', 'rua', 'infantil', 'amb'] la
# ['tot', 'el', "'", 'carinyo'] '
# ['indústria', 'es', 'dedica', 'a'] vendre
# ['0,4%', ',', 'amb', 'la'] qual
# ['faltes', 'de', 'lesions', '</s>'] <s>
# ['fer', 'més', 'competitiva', 'la'] velocitat
# ['de', 'la', 'crema', 'la'] tropa
# ['El_Berguedà', 'pot', 'situar', 'la'] ciutat
# ['per', 'cinc', 'serbis', 'acusats'] d'
# ['va', 'considerar', '"', 'traumàtica'] ni
# ['per', 'treballar', "'", '</s>'] <s>
# ['ahir', 'al', 'vespre', 'autoritats'] del
# ['responsable', 'del', 'xoc', 'per_tal_que'] la_seva
# ['mariscal', 'portuguès', ',', 'va'] néixer
# ['la', 'integració', 'de', 'la'] immigració
# ['factors', 'psiquicoculturals', '</s>', '<s>'] Es
# ['equip', 'blanc', 'i', 'una'] selecció
# ['imatges', 'en', 'color', 'en_directe'] </s>
# ['de', 'la', 'qual', 'seria'] assegurar
# ['<s>', 'Jo', 'prometo', 'el_meu'] vot
# ['La', 'publicació', 'també', 'posa'] a
# ['president', 'del', 'Col·legi_de_Veterinaris_de_Girona', 'en'] el
# ['a', 'la', 'capital', 'del'] Montsià
# ['tenen', 'per', 'la', 'incessant'] aparició
# ['hi', 'és', 'i', ','] per_tant
# ['en', 'els', 'entrenaments', "d'"] Austràlia
# ['Les_seves', 'fotografies', 'es', 'podran'] veure
# ['Mercedes', '</s>', '<s>', 'Pernas'] s'
# ['festa', ',', 'que', 'se'] celebra
# ['<s>', 'Els', 'altres', 'quatre'] directius
# ['juguem', 'una', 'part', 'important'] de
# ['que', 'es', 'caracteritzaran', 'i'] diferenciaran
# ['llibertat', 'sexual', '</s>', '<s>'] Gràcies_a
# ['amb', 'el', 'medi_ambient', ','] encara_que
# ['estètics', 'i', 'morals', '</s>'] <s>
# ['que', 'les', 'condicions', 'del'] nou
# ['ha', 'recordat', 'al', 'diputat'] que
# ['es', 'faran', 'públiques', '</s>'] <s>
# [',', 'amb', 'exempció', 'de'] determinats
# ['"', 'la', 'legislatura', 'de'] la
# ['feien', 'operacions', 'de', 'tràfic'] de
# ['públiques', 'als', 'ports', '</s>'] <s>
# ['què', "l'", 'autor', "s'"] inspira
# ['la', 'direcció', 'de', 'Iuri_Andrópov'] ,
# ["'", 'les', 'paraules', 'serveixen'] de
# ['Classes_Magistrals', 'a_càrrec_dels', 'alumnes', 'de'] l'
# ['requereix', 'com_a', 'requisit', 'una'] intencionalitat
# ['rànquing', ',', 'amb', 'volums'] de
# ['realitat', 'lingüística', 'de', 'Catalunya'] </s>
# ['cursos', 'el', 'sistema', 'públic'] oferirà
# ['del', 'diputat', 'popular', 'ha'] fet_referència
# ['cosa', 'però', 'no', 'sabia'] què
# ['any', 'va', 'dimitir', 'arran_de'] l'
# ['mitja', 'i', "s'", 'estrenarà'] el
# ['demana', 'que', "s'", 'estableixi'] ,
# ['Govern', 'de', 'la', 'Generalitat'] a
# ["l'", 'any', 'que', 've'] </s>
# ['tenia', "l'", 'obligació', 'de'] fer
# ['els', 'representants', 'del', 'Port_de_Tarragona'] també
# ['visiti', 'amb', 'freqüència', '"'] ,
# ['Generalitat', ',', 'ja_que', 'és'] impropi
# ['han', 'iniciat', 'les', 'obres'] de
# ['El', 'partit', 'va', 'prendre'] cos
# ['milions', 'que', 'costarà', "l'"] operació
# ['la', 'Generalitat', 'no', 'interessava'] pagar
# ['Els', 'principals', 'líders', 'sindicals'] ,
# ['</s>', '<s>', 'Aquest', 'fons'] ha
# ['què', 'pensa', 'fer', 'en'] aquest
# ['celebrada', 'ahir', ',', 'a_favor_de'] Càritas
# ['aprofitament', 'de', 'lloc', '</s>'] <s>
# ['un', 'cor', 'artificial', ','] el
# ['entrades', '</s>', '<s>', 'El'] diputat
# ['relacionats', 'amb', 'els', 'canvis'] en
# ['de', 'seguretat', 'que', 'ajudi'] Putin
# ['com_a', 'inspectors', 'veterinaris', 'de'] la
# ['"', '</s>', '<s>', 'Un'] d'
# [',', 'una', 'obra', 'que'] es
# ['estat', ',', 'sens_dubte', ','] l'
# ['cosmètica', 'que', 'permet', 'a'] CiU
# ['confirmat', 'que', 'les', 'estatuetes'] van
# [',', 'la', 'Casa_de_Juntes', 'de'] Gernika
# [',', 'Televisió_de_Catalunya', ',', 'que'] comparteix
# ['majoria', 'dels', 'contractes', 'temporals'] que
# ['població', "d'", 'entre', '26.000'] i
# ['més', 'oberta', 'de', 'la'] Constitució
# ['la', 'Policia_Local', ',', 'els'] mossos
# ['El', 'Centre_de_Cultura_Contemporània_de_Barcelona', 'CCCB', 'serà'] l'
# ['possible', ',', "d'", 'una'] proposta
# ['articular', 'amb', 'tota', 'claredat'] les
# ['<s>', 'A_més_a_més', ',', 'els'] pisos
# ['Riembau', ',', 'dirigit', 'per'] monitors
# ['com_a', 'llaminadures', 'estacionals', ','] han
# ['aire', 'a', 'Ceuta', 'i'] els
# ['un', '70%', 'de', 'la'] producció
# [',', 'que', 'afecta', 'el'] Pla_Especial_Camí_de_la_Cova
# ['els', 'Telenotícies', 'la', 'joia'] de
# ['perfil', 'urbà', ',', 'en'] jardins
# ["'", 'la', 'societat', 'continuï'] contemplant
# ["l'", 'efecte', 'inflacionista', 'del'] cru
# ['ritme', 'de', 'treball', 'els'] sembla
# ['sanitat', ',', 'suport', 'als'] sectors
# ['de', 'Robert_Atkins', 'EEUU', ','] especialista
# ['mocions', 'poden', 'tenir', 'èxit'] en
# ['comarca', '</s>', '<s>', 'El'] jurat
# ['acostar', 'a', 'dos', 'policies'] de
# ['no', 'és', 'atribuïble', 'al'] regidor
# ["s'", 'ha', 'de', 'descartar'] que
# ['què', '</s>', '<s>', 'Crec'] que
# ['les', 'escoles', 'de', 'Música'] de
# ['la', 'mà', 'de', "l'"] Equip_de_Reconstrucció_Històrica
# ['Quan', 'ens', 'movem', 'al_voltant_del'] 3%
# ['trets', 'més', 'remarcables', 'del'] paper
# ['Ariadna', 'i', 'del', 'grup'] de
# ['als', 'xilens', 'que', 'tenen'] "
# ['</s>', '<s>', 'El', 'judici'] ha
# ['vol', 'accentuar', 'el', 'que'] es
# ['càrnic', 'per', 'a', 'millorar'] la
# ['alimentació', ',', 'van', 'tenir'] ahir
# ['firma', 'catalana', 'pretén', 'gestionar'] 23
# [',', 'la', 'Gran_Bretanya', ','] Espanya
# ['un', 'càrrec', 'perquè', 'considera'] que
# ['Molins_de_Rei', 'a', 'Caldes', ','] al
# ['sigui', 'la', 'independència', ','] la
# ['de', 'la', 'localitat', "d'"] Olesa_de_Montserrat
# ['a', 'la', 'xarxa', 'bàsica'] ,
# ['pàgines', ',', 'de', 'gran'] qualitat
# ['<s>', 'En', 'aquest', 'sentit'] ,
# ['Dos', 'CD', '</s>', '<s>'] 41
# ['hagut', 'de', 'diversificar', 'la_seva'] economia
# ['<s>', 'Fins_i_tot', 'la', 'mateixa'] oligarquia
# ['a', 'sobre', '111.000', 'pessetes'] en
# [',', 'encara_que', 'tenim', 'una'] diferència
# ['i', 'Juan_José_López_Burniol', ',', 'president'] de
# ['les', 'vendes', '</s>', '<s>'] Marc_Grau
# ['<s>', 'El', 'trasplantat', 'va'] morir
# ['mateix', 'es', 'va', 'posar'] -
# ['idiomes', '</s>', '<s>', 'La'] Policia_Local
# ['Solsonès', "'", '</s>', '<s>'] Serra
# ['2', 'de', 'Barcelona', 'contra'] Olga_Ros
# ['al', 'públic', '</s>', '<s>'] El
# ['les', 'eleccions', 'de', '2003'] i
# ['inaugurals', ',', 'totes', 'les'] autoritats
# ['Hi', 'ha', 'el', 'PSC'] ,
# ['que', 'té', 'més', 'pes'] de
# ['denuncia', "l'", 'entitat', '</s>'] <s>
# ['"', ',', 'va', 'declarar'] a
# ['conferències', 'sobre', 'els_seus', 'viatges'] ,
# ['de', '12', 'a', '15'] anys
# ['força', 'política', '-', 'amb'] el
# ['patrimoni', 'natural', 'i', 'que'] ,
# ['54', '</s>', '<s>', 'La'] remodelació
# [',', 'per', 'la_seva', 'iniciativa'] ,
# ['el', 'proper', '16_de_juny', 'a'] Madrid
# ['"', 'un', 'càstig', '"'] ,
# ['acusada', 'de', 'les', 'màximes'] i
# ['que', 'Larredonda', 'va', 'afimar'] que
# ['aigua', 'per', "l'", 'antiga'] via
# ['va', 'confirmar', 'que', "l'"] acció
# ['institucional', 'va', 'ser', 'emesa'] pel
# ['<s>', 'Sense', 'aquestes', 'operacions'] ,
# ['dit', 'el_seu', 'president', ','] Lluís_Badia
# ['vergonya', 'de', 'Frank_de_Boer', ','] que
# ['adona', 'de', 'la', 'poca'] visibilitat
# ['només', 'recull', '"', 'generalitats'] "
# ['per', 'anunciar', 'la', 'data'] de
# ['dues', 'entitats', 'organitzadores', 'han'] aclarit
# ['fabrica', 'les', 'peces', 'Lois'] i
# ['informació', 'no', 'té', 'fonament'] </s>
# ['aquí', 'on', 'el', 'màxim'] dirigent
# [',', 'assegura', 'Boi_Fusté', ','] president
# ["l'", 'establiment', 'de', 'mecanismes'] de
# ['12,2', 'euros', 'en', 'monedes'] </s>
# ['vols', 'en', 'helicòpter', ','] globus
# ['dir', 'que', 'és', 'un'] debat
# ["d'", 'aclarir', 'és', 'si'] l'
# ['de', 'floret', ',', 'segurament'] perquè
# ["l'", 'actuació', 'de', 'la'] grua
# ['Meritxell_Yanes', '</s>', '<s>', 'El'] Departament_de_Cultura
# ['constaten', 'que', 'el', 'Palau'] és
# ['el_nostre', 'objectiu', 'és', "l'"] expansió
# ['en', 'el', 'cas', 'concret'] dels
# ['afiliats', 'els', 'autònoms', 'empresaris'] que
# ['<s>', 'Aquest', 'servei', 'constaria'] de
# ['el', 'president', 'de', "l'"] Autoritat_Portuària
# ['la', 'imminència', "d'", 'un'] conflicte
# ['des_de', 'les', '9_del_matí', 'a'] les
# ['per', 'la', 'cintura', "'"] la
# ['Saeb_Erakat', 'i', 'Ahmad_Karei', ','] que
# ['que', 'diu', 'i', 'no'] diu
# ['sindicals', ',', 'el', 'president'] andalús
# ['gruix', 'de', 'les', 'campanyes'] institucionals
# ['firma', 'familiar', 'de_cara_als', 'pròxims'] exercicis
# ['que', 'es', 'mantindrà', 'per'] la_seva
# ['productes', 'energètics', ',', 'amb'] un
# ['de', 'carbó', ',', 'Jones'] ha
# ['un', 'dels', 'detinguts', 'de'] la
# ['conseller', 'de', 'Sanitat', ','] Eduard_Rius
# ['deixarà', 'el_seu', 'càrrec', 'de'] president
# ['<s>', 'Els', 'pacifistes', 'consideren'] que
# ['considera', ',', "l'", 'okupació'] no
# ['telèfon', 'o', 'un', 'altre'] mitjà
# ['Govern', '-', 'amb', 'la'] venda
# ['sector', 'turístic', ';', 'difondre'] les
# ['nombre', 'de', 'visitants', 'i'] ha
# ['política', 'basca', '</s>', '<s>'] Som
# ['recurs', "d'", 'alçada', 'i'] una
# ['avituallament', ',', 'el', 'dinar'] i
# ['rector', 'és', 'majoritàriament', 'desqualificat'] </s>
# ['Luis_del_Olmo', ',', "a_través_d'", 'Onda_Rambla'] </s>
# ['i', 'per', 'les', 'subvencions'] institucionals
# ['la', 'qual', 'va', 'pertànyer'] Vladímir_Putin
# ['i', 'prop', 'de', '300'] fotografies
# ['aportar', 'un', 'ampli', 'ventall'] de
# ['afectar', 'els', 'éssers', 'humans'] </s>
# ['tenora', 'acompanyaran', 'Arnella', 'a'] l'
# ['dels', 'insectes', 'o', 'de'] les
# ['trimestre', 'de', "l'", 'any'] passat
# ['</s>', '<s>', 'Practiquen', 'el'] vodú
# ['condicions', 'que', 'no', 'es'] donen
# ['aquesta', 'política', 'de', 'pactes'] perquè
# ['a', 'aquest', 'percentatge', '"'] </s>
# ["'", 'i', 'ha', 'demanat'] la
# ['la', 'mateixa', 'consellera', '-LSB-'] de
# ['<s>', 'Interrogada', 'a', "l'"] atzar
# ['un', 'terreny', 'imaginari', 'on'] la
# ['lliure', 'accés', ',', 'ofereix'] un
# ['és', 'una', 'de', 'les'] quatre
# ['la', 'informació', 'en', 'els'] resums
# ['un', 'altre', 'de', 'canadenc'] confirmen
# ['part', 'de', "l'", 'any'] a
# ['entre', '300', 'i', '600'] milions
# ['adhesió', "d'", 'aquesta', 'institució'] a
# ['primer', 'i', 'segon', 'per'] sèrie
# ['els', 'terrenys', 'de', 'la'] Botjosa
# ['reclamar', 'la', 'inclusió', 'de'] la
# ['evitar', 'agressivitats', '</s>', '<s>'] Ho
# ['diabètics', 'més', 'joves', '</s>'] <s>
# ['això', 'pot', 'suposar', 'la'] paralització
# ['un', 'ritme', 'escènic', 'trepidant'] ,
# ['informació', 'controlada', 'pel', 'govern'] de
# ['per', 'la', "Fundació_per_una_Nova_Cultura_de_l'_Aigua", 'sobre'] els
# ['</s>', '<s>', 'En', 'la_seva'] edició
# ['menys', 'marge', 'per', 'elegir'] </s>
# ['ser', 'un', 'dels', 'pioners'] </s>
# ['Costa_Brava', ',', 'que', 'és'] coneguda
# ['elèctric', ',', 'i', 'llavors'] se
# ['volums', 'de', 'la', 'Divina_Comèdia'] de
# ['com_a', 'mostra', 'de', 'nerviosisme'] ,
# ['Redondo', 'reprotxa', 'al', "'"] lehendakari
# ['El', 'conjunt', 'vendrellenc', 'intervindrà'] al
# ['més', 'control', "d'", 'armes'] ,
# ['els', '60', 'voluntaris', 'sortirà'] des_del
# ['El', 'campament', 'reial', 'es'] dividirà
# ['la', 'companyia', 'han', 'afegit'] que
# ['sotmès', 'a', 'una', 'intervenció'] neuroquirúrgica
# ['endarrerit', 'el', 'procés', 'de'] reclamació
# ['promoure', 'el_seu', 'nou', 'negoci'] per
# ['ús', 'públic', 'dels', 'parcs'] que
# ['per', 'una', 'enquesta', 'que'] revela
# ['sotmetran', 'a', 'un', 'acarament'] judicial
# [',', 'Jordi_Follia', ';', 'i'] del
# ['entorn', 'de', 'protecció', '</s>'] <s>
# ['a', 'la', 'B-204', ','] al
# ['</s>', '<s>', 'Des_de', 'Lleida'] ,
# ['que', 'va', 'ser', 'condemnat'] a
# ['de', 'contractació', ',', "l'"] estudi
# ['i', '1.080.000', 'pessetes', 'de'] multa
# ['en', 'súper_vuit', 'de', 'La_isla_de_las_almas_perdidas'] ,
# ['de', 'caixes', '</s>', '<s>'] "
# ['vuitanta_per_cent', 'del', 'capital', '</s>'] <s>
# ['debat', 'que', "s'", 'ha'] obert
# ['dipòsits', 'dels', 'compradors', "d'"] uns
# ['del', 'municipi', ',', 'Antoni_Padilla'] ,
# [',', 'de', 'Torredembarra', '</s>'] <s>
# ['a', "l'", 'Encanyissada', 'per'] aportar
# ['<s>', 'El', 'president', "d'"] IC-V
# ['dut_a_terme', 'CiU', 'davant', 'el'] PP
# ['que', 'no', 'hi', 'ha'] res
# ["L'", 'home', 'va', 'resultar'] greument
# ["l'", 'exploració', 'visual', 'de'] les
# ['el_seu', 'càrrec', 'i', 'serà'] substituït
# ['sempre', "s'", 'ha', 'declarat'] '
# ['i', 'dos', 'helicòpters', ','] va
# ['del', 'lli', 'no', 'la'] fan
# ['bisbe', 'auxiliar', 'del', 'Barcelonès_Nord'] ,
# ['de', 'llei', 'del', 'PSC-CpC'] en
# ['més', 'que', 'el', '1997'] ,
# ['estudis', 'han', 'anat', 'a_càrrec_del'] Centre_Tecnològic_Forestal_de_Catalunya
# ['la', 'riera', "'", '</s>'] <s>
# ['Unió_de_Pagesos', ',', 'Joves_Agricultors_i_Ramaders_de_Catalunya', 'JARC-Asaja'] ,
# ['Un', 'mal', 'insuportable', '</s>'] <s>
# ['2006', ',', 'per', 'trobar'] una
# [',', 'el', 'secretari', 'del'] jurat
# ["d'", 'energia', 'que', 'se'] situa
# ['millora', 'dels', 'camins', 'i'] accessos
# ['més', 'racional', 'que', 'això'] dels
# ['pel_que_fa_a', 'vacunació', ',', 'tal_i_com'] es
# ['el', 'Rei', ',', 'el'] 1976
# ['treball', ';', 'en', 'homenatge'] a
# ['"', 'com', 'una', 'locomotora'] "
# ['en', 'la', 'rehabilitació', 'dels'] edificis
# ['284', 'milions', 'de', 'pessetes'] </s>
# ['El', 'municipi', 'de', 'Badia_del_Vallès'] té
# ['ciutadania', 'es', 'va', 'quedar'] a
# [',', 'només', 'és', 'possible'] convocar
# ['les', 'associades', 'a', "l'"] AMEC
# ['</s>', '<s>', 'Aquestes', 'empreses'] ,
# ['La', 'turista', 'japonesa', 'Ito_M.'] ,
# ['metres', 'es', 'convertiran', 'en'] carrers
# ['<s>', 'He', 'compartit', 'les'] inquietuds
# ['elecció', 'dels', 'nou', 'membres'] del
# [',', 'les', 'greus', 'de'] fins_a
# ['</s>', '<s>', 'El', 'diputat'] d'
# ['dent', '</s>', '<s>', 'El'] Monarca
# ['en', 'termes', 'nominals', ','] el
# ['<s>', 'Pel_que_fa_a', "l'", 'índex'] sobre
# ['agrari', '</s>', '<s>', 'En'] aquest
# [',', 'que', 'han', 'assenyalat'] que
# ['organisme', 'internacional', 'antidopatge', 'del'] qual
# ['afectats', '</s>', '<s>', 'En'] aquest
# ['accions', '"', 'per', 'reduir'] les
# ['acabar', 'amb', 'la', 'vida'] de
# [',', 'ha', 'postil·lat', 'posant_en_relleu'] el
# ['el', 'més', 'adequat', 'per'] cantar
# [',', 'i', 'el', 'Canal_Internacional'] de
# ['cosa', 'més', 'que', 'un'] organisme
# ['Aleshores', 'el_seu', 'pare', 'va'] fer
# ['barri', 'de', 'Lloreda', 'i'] 5
# ['any', 'passat', 'activitat', 'per'] a
# ['definició', ',', 'problemàtiques', ','] la
# ['nacional', '340', 'al', 'terme'] d'
# ['en_relació_a', 'la', 'utilització', 'de'] recursos
# ['La', 'mare', 'de', 'Rocío'] ,
# ['general', "d'", 'Unió_Democràtica_de_Catalunya', ','] Marta_Llorens
# ['com', 'sóc', '</s>', '<s>'] El_meu
# ['</s>', '<s>', 'Gabi_Ruiz_Bernal', ','] de
# ['els', 'propers', 'quatre', 'anys'] </s>
# ['partit', 'ha', 'reiterat', 'que'] un
# ['de', 'les', 'conferències', ','] programada
# ['El', "Cos_d'_Agents_Rurals_del_Departament_de_Medi_Ambient", 'ha', 'interceptat'] aquesta
# ['<s>', 'Duran', 'ja', 'va'] rebre
# ['són', 'conseqüents', '"', 'amb'] les
# ['ahir', 'els', 'canvis', 'que'] s'
# ['la', 'guerra', 'a', 'Txetxènia'] ,
# ['base', 'pedagògica', 'adreçada', 'a'] joves
# ['de', 'Rossini', ',', 'a_càrrec_del'] cor
# ['a', 'la', 'nova', 'residència'] de
# ['caracteritzen', 'amb', 'més', 'o'] menys
# ['aquesta', 'manera', '-', 'diuen'] els
# ['hi', 'ha', 'una', 'empresa'] de
# ['setze', 'dirigents', 'més', "d'"] ERC
# ['anys', ',', 'els', 'solutrians'] s'
# ['havien', 'ensorrat', 'completament', 'amb'] aquesta
# ['vols', 'xàrter', 'als', 'ja'] saturats
# ['el', 'màxim', 'que', 'es'] pot
# ['fe', 'mou', 'muntanyes', "'"] ,
# ['un', 'canal', 'de', 'televisió'] de
# ['donar', '-li', "'", '</s>'] <s>
# ['renovació', 'i', "l'", 'ampliació'] de
# ['abocaments', 'de', 'purins', 'a'] la
# ['durant', 'la', 'campanya', '2000'] fan
# ['han', 'incomplert', 'el', 'que'] s'
# ['No', 'ens', 'podem', 'limitar'] a
# ['de', 'funcionament', 'dels', 'Plans_de_Transició_al_Treball'] i
# ['subvenció', 'podien', 'ser', 'tots'] els
# ['en', 'el', 'Govern', "'"] almenys
# ['"', 'i', 'li', 'va'] dir
# ['Liuva', ',', 'al', 'barri'] de
# ['</s>', '<s>', 'La', 'Generalitat'] construirà
# ['perspectives', 'de', 'victòria', 'i'] la
# ['fantàstica', 'aventura', '"', '</s>'] <s>
# ['nit', 'al', 'municipi', 'de'] L'_Albagés
# ['viu', ':', 'Luís_Maria_Anson', ','] avui
# ['llei', 'en', 'què', 'insta'] el
# ["'", '</s>', '<s>', 'Els'] responsables
# ['molt', 'enamorats', '"', ','] va
# ['</s>', '<s>', 'Els', 'Ferrocarrils_de_la_Generalitat'] incrementaran
# ['investigadors', 'per', 'aconseguir', 'fotografiar'] les
# ['van', 'tancar', "l'", 'any_1999'] amb
# ["d'", 'acord', 'que', 'està'] basada
# ['estudi', 'sobre', 'la', 'toxicitat'] d'
# ['<s>', '50', 'films', 'participen'] en
# ['del', 'director', 'general', 'de'] la
# ['36', 'anys', "d'", 'edat'] ,
# ['marxa', ',', 'en', 'un'] semàfor
# ['llistes', "d'", 'espera', 'sanitàries'] ,
# ['se', 'sent', '"', 'destrossat'] pel
# [',', 'però', 'que', 'mai'] no
# ['<s>', 'També', 'està', 'previst'] distribuir
# ['evoluciona', 'favorablement', ',', 'igual'] que
# [',', 'abandonat', 'des_de', 'fa'] tres
# ['</s>', '<s>', 'La', 'gran'] part
# ['es', 'compromet', 'a', "'"] divulgar
# ['novembre', 'uns', '200.000', 'metres'] cúbics
# ['10', 'CD', '</s>', '<s>'] Document
# ['costaran', '25.000', 'milions', 'de'] pessetes
# ['qual', ',', 'naturalment', ','] no
# ['no', 'assemblearis', 'troba', "'"] inadmissible
# ['París', 'i', 'a', 'Lió'] i
# ['França', ',', 'per', 'la'] qual
# ["'", '</s>', '<s>', 'En'] aquest
# ['el', 'metge', ',', 'els'] dos
# ['sentit', 'que', 'els', 'EUA'] no
# ['salut', ',', 'per', 'fer'] un
# [',', 'produïnt', 'uns', 'enormes'] canvis
# ['Pujol', 'en_matèria_de', 'finançament', 'autonòmic'] per
# ['de', 'pessetes', '</s>', '<s>'] Endesa
# ['insistir', 'que', 'les', 'retallades'] es
# ['<s>', "L'", 'única', 'dada'] negativa
# ['ha', 'assenyalat', 'que', "'"] lamentem
# ['Aquest', 'concert', 'serà', 'el'] que
# ['a', "l'", 'activitat', 'portuària'] de
# ['arrencada', 'del', 'reactor', 'nuclear'] no
# ['alarmista', 'i', 'centrar', '-se'] en
# ['home', 'assassina', 'a', 'Albacete'] la_seva
# ['al', 'Govern', ',', 'per'] una
# ['es', 'mostra', 'decebut', "'"] a
# ['arribar', 'a', 'la', 'meta'] de
# ['desmarcar', 'dels', 'arguments', 'del'] nou
# ["l'", 'Incasol', 'al', 'barri'] del
# ['rebre', 'ahir', 'a', 'Sevilla'] en_qualitat_d'
# [',', 'i', 'anys', 'més'] tard
# ['</s>', '<s>', 'El', 'jutge'] destaca
# ['<s>', 'La', 'campanya', '2000'] de
# ['aquesta', 'situació', ',', "l'"] home
# ['en', "l'", 'auditori', 'i'] sala
# ['nacionalistes', '</s>', '<s>', 'El'] PNB
# ['ja', 'ha', 'guanyat', 'la_seva'] primera
# ['cap', 'de', 'setmana', 'a'] Sitges
# ['de', 'la', 'localitat', '</s>'] <s>
# ['i', 'el', 'de', 'Can_Ruti'] ,
# ['fa', 'témer', 'que', 'es'] repeteixin
# ['entitat', 'cívico-econòmica', 'que', 'impulsi'] la
# ['personalitats', 'i', 'representants', "d'"] entitats
# ['moviment', 'Pàtria_i_Llibertat', ',', 'que'] va
# ['línies', 'habitual', ',', 'les'] lliçons
# ['ser', 'decisius', '</s>', '<s>'] La
# [',', 'Lluís_Martínez_Sistach', ',', 'parla'] del
# ['la', 'sèrie', "d'", 'un'] dels
# ['realització', 'i', 'de', 'recerca'] de
# ['partit', '</s>', '<s>', 'Això'] és
# ['una', 'arma', 'que', 'aguantava'] un
# ['baixa', 'densitat', 'de', 'població'] -
# ['les', 'comunitats', 'autònomes', 'i'] dels
# ['i', 'hi', 'haurà', 'un'] desè
# ['cooperativa', 'Copaga', 'i', ','] segon
# ['Alex_Corretja', ',', 'tindrà', 'un'] començament
# ['sense', 'oposicions', '</s>', '<s>'] Dos
# ['més', 'que', 'la', 'música'] ,
# ['<s>', 'Les', 'accions', "d'"] Azkoyen
# ['ni_tan_tan_sols', 'haver', 'anat', 'a'] les
# ['posteriorment', ',', 'ja', 'al'] carrer
# ['Economia', 'de', 'la', 'Generalitat'] ,
# ['quan', 'Jaume_Sodupe', 'era', 'conseller'] delegat
# [',', 'associacions', 'i', 'revistes'] per
# ['No', 'és', 'un', 'cas'] nou
# ["d'", 'una', 'iniciativa', 'que'] fa
# ['segons', 'Flores', ',', '"'] encara_que
# ['<s>', 'Una', 'demanda', 'per'] violació
# ['elaborat', 'per', "l'", 'ocasió'] </s>
# ['les', 'responsabilitats', 'del', 'general'] Pinochet
# ['Ex_Von_Szerdahely_VieuxTemps', ',', 'del', '1736'] </s>
# ['al', 'municipi', 'de', 'Vilaverd'] Conca_de_Barberà
# ['dels', 'lectors', 'per', 'tota'] mena
# ['una', 'dramatització', 'de', 'la'] sèrie
# ['de', 'dret', '"', '</s>'] <s>
# ['El', 'Síndic', 'no', 'ha'] precisat
# ['per', 'les', 'abelles', '</s>'] <s>
# ['Congrés', ',', 'el', 'debat'] existeixi
# ["d'", 'iniciativa', 'pública', ','] també
# ['any', 'en', 'què', 'es'] va
# ['de', 'Viladasens', ',', 'Josep_Lladó'] ,
# ['als', 'sol·licitants', 'és', 'la'] que
# ['aquest', 'sentit', ',', 'ha'] afegit
# ['del', 'romànic', '</s>', '<s>'] La
# ['<s>', 'I', 'una', 'prevenció'] deficient
# ['situarà', 'al', "Portal_de_l'_Àngel", ','] i
# [',', 'que', 'el', 'que'] persegueix
# ['</s>', '<s>', 'Des_de', 'principis'] d'
# ['en', 'la', 'decisió', 'del'] Tribunal_d'_Apel·lacions
# ['Suïssa', 'o', 'importants', 'empreses'] </s>
# ["l'", 'odi', 'del', 'seu'] etern
# ['el', 'que', 'tenim', 'ara'] "
# ['<s>', 'El', 'metge', 'que'] va
# ["Denominació_d'_Origen", 'i', 'dos', 'periodistes'] gastronòmics
# ['en', 'una', 'tendència', 'contestatària'] interna
# ['comissari', "d'", 'agricultura', 'europeu'] ,
# ['és', 'la', 'retirada', 'militar'] jueva
# ['una', 'antiga', 'reivindicació', 'dels'] veïns
# ['</s>', '<s>', 'Durant', 'el'] matí
# ['de', 'formigó', 'perquè', 'la'] quantitat
# ['de', 'les', 'obres', 'seleccionades'] pel
# ['passaran', 'els', 'grups', 'participants'] en
# ['des_del', 'punt', 'de', 'vista'] terapèutic
# ['en', '9.038', '</s>', '<s>'] A
# ['cos', 'va', 'ser', 'introduït'] a
# [',', 'el', 'taxista', 'testimoni'] del
# ['amb', 'vocació', 'de', 'continuïtat'] i
# ['1.839', '-1,91_%', 'sobre', "l'"] abril
# ['<s>', 'Zinedine_Zidane', 'no', 'podrà'] jugar
# ['filòleg', 'i', 'escriptor', ','] Xavier_Grasset
# ['estem', 'avesats', 'a', 'Europa'] "
# ['recordar', 'un', 'fragment', 'del'] manifest
# ['descartar', 'que', 'hi', 'hagués'] hagut
# ["d'", 'ocells', 'estepàries', 'que'] es
# ['de', 'manera', 'directa', 'o'] indirecta
# ['ahir', 'va', 'sumar', 'el'] novè
# ['locals', "'", '</s>', '<s>'] No_obstant
# ['i', 'el', 'sotsdirector', 'de'] Règim
# ['<s>', 'Horta_Confecció_,_SCCL', ',', "d'"] Horta_de_Sant_Joan
# ['dels', 'estudis', 'adients', 'sobre'] el
# ["Govern_de_l'_Estat", '"', '</s>', '<s>'] L'
# ['fitxes', "'", 'perquè', 'tan_sols'] hi
# ['és', 'la', 'protecció', 'i'] el
# ['espai', 'informatiu', 'En_clave_actual', 'i'] va
# ['programa', 'europeu', ',', 'denominat'] Reflex_2000-2003
# ['sindicat', 'del', 'metall', ','] la
# ['repetir', 'la', 'gesta', 'de'] la
# ['pessetes', '</s>', '<s>', 'La'] presència
# ['una', 'major', 'claredat', 'política'] des_del
# ['</s>', '<s>', 'A', 'la'] serra
# ['obra', ',', 'en', 'les'] quals
# ['dos', 'documents', 'titulats', '"'] I.M.
# ['mig', 'de', 'pessetes', ','] i
# ['situen', 'les', 'agències', 'de'] viatges
# ['també', 'nadalenca', "d'", 'Alessandro_Scarlatti'] </s>
# ['agressiva', '</s>', '<s>', 'Quan'] es
# ['han', "d'", 'implicar', 'en'] la
# ['helicòpter', 'i', ',', 'si'] les
# [',', 'per', 'haver', '-se'] beneficiat
# ["l'", 'individu', 'no', 'hi'] tocava
# [',', "l'", 'equip', "d'"] inspectors
# [',', 'els', 'deutes', 'a'] curt
# ['cas', 'de', 'Sabadell', 'Vallès_Occidental'] ,
# ['implicació', 'en', 'una', 'trama'] destinada
# ["l'", 'avortament', '"', ','] cosa
# ['del', 'país', ',', 'va'] dir
# ['</s>', '<s>', 'Amb', 'aquestes'] dades
# ['</s>', '<s>', '"', 'No'] li
# ['escola', 'de', 'Milanello', ','] li
# ['diumenge', 'morís', 'una', 'jove'] de
# ['<s>', 'Bonino', 'adverteix', 'contra'] la
# ['la', 'Universitat_de_Vic', ',', 'Ramon_Coy'] ,
# ['un', 'refredament', 'de', "l'"] economia
# ['servir', 'per', 'solucionar', '28'] casos
# ['Pel_que_fa_a', 'la', 'resta', ','] el
# ['algues', '</s>', '<s>', 'Els'] peixos
# ['</s>', '<s>', 'Entre', 'ells'] parlaven
# ['"', 'que', 'ha', "d'"] exercir
# ['-', 'en', 'una', 'societat'] plenament
# ['al', 'segle', 'vinent', ','] però
# ['tornar', 'al', 'pis', 'de'] Santa_Coloma_de_Gramenet
# ['la', 'multinacional', 'holandesa', 'llançarà'] un
# ['al', 'Delta', "'", '</s>'] <s>
# ['ser', 'conservatoris', '</s>', '<s>'] Les
# ['canvis', 'que', 'hem', 'fet'] sempre
# ['per', 'voluntat', 'expressa', 'de'] l'
# ['la', 'societat', 'de', 'la'] informació
# ['dur', 'tornar', '-hi', '"'] </s>
# ['actuar', 'amb', 'Ben_Waltzer', 'al'] cicle
# ['<s>', 'Segons', 'el', 'sindicat'] ,
# ['augmentar', 'el', 'negoci', 'no'] té
# ['José_María_Aznar', 'i', 'amb', 'el'] PP
# ['relació', 'amb', "l'", 'Ajuntament_de_Reus'] </s>
# ['produït', 'notícies', "d'", 'aquesta'] índole
# ['Vicente_Rodríguez_Arribas', ',', 'va', 'quedar'] ahir
# ['horaris', 'comercials', 'que', 'segons'] la
# [',', 'la', "d'", 'Humanitats'] ,
# ['que', 'ha', 'despertat', 'després'] de
# ['Teresa_Pou', '</s>', '<s>', 'El'] president
# ['cada', 'centre', 'podia', 'seleccionar'] un
# ['a', 'Catalunya_Ràdio', ',', 'en'] al·lusió
# [',', 'davant', 'dels', '28'] dies
# ['que', 'li', 'aportava', "l'"] administració
# [',', 'qui', 'ha', 'celebrat'] que
# ['parlant', 'del', 'fill', 'del'] president
# ['temes', 'com', 'la', 'no'] concessió
# ['dels', 'destins', 'que', 'cobreix'] aquesta
# ['Comissió_Europea', 'considera', 'tranquil·litzador', 'que'] la
# ['haver', 'atracat', 'amb', 'una'] navalla
# ['fa', 'uns', 'dies', 'a'] la
# ['principal', 'de', 'Gibraltar', ','] Peter_Caruana
# [',', 'el', 'va', 'deixar'] fora
# ['dels', '1.300', 'exemplars', 'del'] catàleg
# ['de', 'Països_Catalans', ',', 'Pep_Ventura'] ,
# ['la', 'del', 'primer', 'alcalde'] democràtic
# ['Osona', 'promogut', 'per', "l'"] ajuntament
# ['ressaltat', 'la', 'importància', 'de'] les
# ['que', 'va', 'indicar', 'ahir'] a
# ['Gabino_de_Lorenzo', ',', 'també', 'del'] PP
# ['tal', "'", 'que', 'li'] van
# ['el_seu', 'advocat', ',', 'Santiago_Puig'] ,
# [',', "s'", 'anuncia', 'que'] "
# ['seleccionat', 'ja', 'els', 'receptors'] </s>
# ['donen_resposta', 'a', 'un', 'procés'] d'
# ['no', 'tenen', 'més', 'risc'] de
# ['un', 'forn', 'a', 'Reus'] </s>
# ['de', 'les', 'altres', 'dues'] poblacions
# ['primeres', 'teles', 'fins_a', 'les'] que
# ['de', "l'", 'operació', 'militar'] israeliana
# ['equatoguineà', 'Severo_Moto', 'al', 'jutge'] Baltasar_Garzón
# ['a', '9,7', 'milions', 'de'] pessetes
# ['criticat', 'la', "'", 'creixent'] politització
# ['espectacle', 'del', 'mateix', 'títol'] ,
# ['cultura', 'catalanes', 'a', 'la'] xarxa
# ['una', 'renovació', 'sobretot', 'en'] els
# ["'", 'connivència', "'", 'amb'] la
# ['se', 'situarà', 'al', 'petit'] llac
# ['</s>', '<s>', '"', 'Si'] hi
# ['"', 'les', 'mans', 'lliures'] "
# ['de', 'protegir', 'la', 'biodiversitat'] en
# ["d'", 'agafar', 'volada', 'per'] la
# ['per', 'primera', 'vegada', 'en'] els
# ['per', 'poder', 'incrementar', 'la'] producció
# ['Estat', 'provingui', "d'", 'empreses'] catalanes
# ['retirada', 'israeliana', 'dels', 'territoris'] del
# [',', 'com', 'la', 'de'] la
# ['Jo', 'en_principi', 'no', 'dic'] ni
# ['de', "l'", 'economia', 'internacional'] ,
# ['un', 'Guadagnini', 'o', "d'"] un
# ['de', 'la', 'Fira', ','] van
# [',', 'Fox', 'en', 'va'] sortir
# ['celebrat', 'avui', 'a', 'la'] secció
# ['patrocini', 'de', 'parcs', 'naturals'] a_través_d'
# ['buscant', 'noves', 'espècies', '</s>'] <s>
# ['Clearing', ',', 'La_Caixa', 'i'] El_Corte_Inglés
# ['Audiència_de_Barcelona', 'ha', 'condemnat', 'a'] 1
# ['zona', 'cremada', 'en', "l'"] incendi
# [',', 'la', 'tradicional', 'hebrea'] i
# [';', "s'", 'ha', 'de'] demanar
# ['plorant', 'que', 'sabia', 'que'] li
# ['caramels', 'en', 'forma', "d'"] activitats
# ['de', 'Teresa_Serra', 'per', 'ensenyar'] -li
# ['<s>', 'Molt', 'cara', 'li'] ha
# ['provocat', 'el_seu', 'ingrés', 'en'] la
# ['opinar', 'el', 'director', "d'"] esports
# ['sigui', 'transparent', 'i', 'efectiu'] -
# ['<s>', 'Uns', '2.500', 'veïns'] del
# ['menys', 'de', '10', 'anys'] ,
# ['ser', 'una', 'festa', 'molt'] entretinguda
# ["l'", 'urbanisme', 'i', "l'"] ordenació
# ['"', 'exòtica', '"', ','] d'_acord_amb
# ['de_cara_a', "l'", 'estiu', '</s>'] <s>
# ['la', 'del', 'programa', 'estrella'] "
# ['que', 'han', 'format', 'els'] músics
# ['Demarcació_de_Barcelona', 'del', 'COAC', ';'] els
# ['la', 'frontera', 'cap_a', "l'"] interior
# ["d'", 'ETA', ',', 'Batasuna'] ha
# ['</s>', '<s>', 'Però', 'encara_que'] la
# ['ciutats', 'com', 'Liverpool', 'i'] Londonderry
# ['sobretot', 'perquè', 'Àustria', 'és'] un
# ['el', 'mateix', 'sentit', "s'"] ha
# ['una', 'proposició', 'no', 'de'] llei
# ['estat', "l'", 'acomiadament', 'del'] finlandès
# ['de', 'pilots', 'SEPLA', 'negociaran'] avui
# ["l'", 'oportunisme', 'més', 'descarnat'] </s>
# ['</s>', '<s>', 'És', 'un'] home
# ['sinó_també', 'perquè', 'seria', 'una'] puta
# ['rellevància', 'a', 'la', 'cultura'] popular
# ['política', ',', 'ja_que', 'es'] declaren
# ['es', 'faci', 'amb', 'una'] visió
# ['policia', 'francesa', 'només', 'va'] informar
# [',', 'Gran_Bretanya', ',', 'o'] els
# ['propis', 'i', 'conscienciar', 'els'] clients
# ['se', 'celebren', 'a', 'Catalunya'] són
# ['</s>', '<s>', 'Aquesta', 'amenaça'] encoberta
# ['hi', 'havia', 'les', 'dependències'] monacals
# ['lectors', '</s>', '<s>', "L'"] exposició
# ['acomiadament', 'del', 'finlandès', 'Mika_Salo'] ,
# ['tres', 'faltes', 'de', 'júnior'] molt
# ['origen', '</s>', '<s>', 'Però'] aquests
# ['patir', '"', ',', 'va'] afegir
# ['mineria', 'que', 'la', 'Unió_Europea'] ha
# ['basada', 'en', 'el', 'diàleg'] que
# ['tremolor', '</s>', '<s>', 'El'] sisme
# ["d'", 'edat', '</s>', '<s>'] Vivia
# ['la', 'societat', 'civil', 'mundial'] en_el_marc_del
# ["d'", 'obligada', 'aplicació', 'la'] nova
# ['enlairar', 'més', 'tard', 'del'] previst
# ['castigades', 'per', 'les', 'institucions'] sueques
# [',', 'pacífica', 'en', 'un'] principi
# ['mort', 'en', 'el', 'terratrèmol'] ,
# ['15_de_setembre_de_1994', ':', 'personal', 'de'] l'
# ['afecta', 'la', 'imparcialitat', 'i'] equanimitat
# ['intervingui', 'perquè', 'el', 'coneixem'] bé
# ['jugador', 'per', 'indisciplina', 'si'] es
# ['controlar', '-les', '</s>', '<s>'] També
# ['i', 'de', 'diferents', 'nacionalitats'] </s>
# ['Espanya', 'tenen', 'la_seva', 'màxima'] implantació
# [',', 'la', 'sèrie', 'ha'] venut
# ["d'", 'aquests', 'fugitius', ','] un
# [',', 'en', 'especial', 'dels'] dirigents
# ['al', 'jugador', 'una', 'casa'] per
# ['mesures', 'per', "'", 'posar'] ordre
# ['en', 'plena', 'funció', 'va'] ser
# ['<s>', 'Davant', 'la', 'por'] que
# ...
# ['acabar', 'junts', '</s>', '<s>'] L'
# ['partit', 'mediocre', '</s>', '<s>'] Hi
# ['ser', 'president', 'de', 'la'] Generalitat
# ['excel·lent', 'en', 'el', '94,4_per_cent'] dels
# ['fantàstic', 'i', 'de', 'terror'] ,
# ['a', 'casa', 'i', 'trobar'] -se
# ['<s>', "D'", 'altra', 'banda'] ,
# ['que', "l'", 'estat', 'comptable'] del
# ['<s>', 'Els', 'candidats', 'a'] construir
# ['resultats', 'de', 'les', 'empreses'] </s>
# ['demanat', ',', 'aquest', 'dilluns'] ,
# ['espai', 'aeri', 'europeu', ','] la
# ['noves', 'relacions', 'laborals', 'derivades'] de
# ['TPI', 'abans', 'del', '31_de_març'] </s>
# ['les', 'intervencions', 'de', 'canvi'] de
# ['al', '8_de_juliol', 'es', 'tractarà'] l'
# ['de', 'les', 'prestacions', 'sanitàries'] que
# ['els', 'pròxims', 'dos', 'anys'] ,
# ['<s>', 'I', 'és', 'que'] ,
# ['teatres', "d'", 'Itàlia', 'com'] la
# ['són', 'gestionats', 'per', 'entitats'] en
# ['<s>', 'Aquesta', 'primera', 'edició'] de
# ['confiar', 'en', 'la', 'gent'] </s>
# ['tot', 'el_seu', 'art', 'galàctic'] ,
# ['organitza', 'la', 'fundació', 'que'] ,
# ['també', 'ha', 'explicat', 'que'] el
# ['actuacions', 'a', 'la', 'Plaça_del_Rei'] de
# ['natura', 'més', 'pròpiament', 'dit'] ,
# ['car', '</s>', '<s>', 'Baix'] pes
# ['Ralf_Schumacher', 'i', 'el', 'tetracampió'] del
# ['algun', 'i', 'distribuir', '-los'] en
# ['A', 'principis', 'dels', 'noranta'] va
# ['hagi', 'centrat', 'només', 'en'] la
# ['va', 'en', 'la', 'línia'] d'
# ['la_seva', 'herència', 'en', 'el'] govern
# ['al', 'processat', ',', 'perquè'] va
# ['va', 'passar', 'al', 'Canadà'] ,
# ['les', 'converses', 'a', "l'"] estranger
# ['ha', 'convocat', 'la', 'vint-i-setena'] edició
# ['reconèixer', 'no', 'fa', 'gaire'] el
# ['¿', 'qui', 'es', 'recorda'] de
# ['"', 'Un', 'amor', 'dramàtic'] ,
# ["'", 'i', "'", 'La_venjança_de_Jesús'] '
# ['</s>', '<s>', 'Es', 'va'] observar
# ['-les', '</s>', '<s>', 'El'] tribunal
# [',', 'Salvador_Obiols', ',', 'i'] els
# ['Segons', "l'", 'anàlisi', 'de'] l'
# ['les', 'empreses', 'espanyoles', '</s>'] <s>
# ['"', 'una', 'autèntica', 'fita'] "
# ['moment', 'en', 'el', 'qual'] la
# ['Bruce_Bradley', 'van', 'revolucionar', 'amb'] la_seva
# ['consubstancial', 'al', 'sistema', 'espanyol'] ,
# ['passar', 'per', 'la', 'carretera'] d'
# ['en', 'record', 'dels', 'avantpassats'] ,
# ['quantitat', 'de', '740', 'milions'] de
# ['any', 'passat', 'només', 'hi'] va
# ['ciència', '</s>', '<s>', 'Per_últim'] ,
# ['que', 'gairebé', 'un', '31_%'] de
# [',', 'una', 'monarquia', 'bananera'] que
# ['assassinat', 'per', 'un', 'grup'] de
# ['estat', 'de', 'Washington', 'Estats_Units'] ,
# ['important', 'menjar', 'bé', '</s>'] <s>
# [':', "l'", 'atur', 'i'] la
# ['les', 'Jornades', 'es', 'presentarà'] la
# ['inauguració', "d'", 'una', 'obra'] hidràulica
# ['i', 'altres', 'que', 'en'] són
# ['perfecte', 'perquè', 'tothom', 'pugui'] tenir
# ['que', 'els', 'de', 'la'] rendibilitat
# ["'", ',', 'el', 'programa'] religiós
# ['rendes', 'amb', 'saldo', 'a'] pagar
# ['conèixer', 'els', 'límits', 'i'] també
# ["d'", 'Internet', 'i', 'novetats'] tecnològiques
# ['la', 'companyia', 'obrirà', 'unes'] 200
# ['operacions', 'de', 'les', '285'] que
# ['el', 'palau', 'del', 'Virrei'] ,
# ['molt', 'fidel', "'", 'de'] la
# ['de', 'miracle', "d'", 'una'] mort
# ['marc', 'de', 'col·laboració', 'entre'] l'
# ['la', 'gravetat', 'del', 'seu'] estat
# ['i', 'zones', 'verdes', ','] mentre_que
# ['o', 'quatre', 'dècades', '"'] </s>
# ["d'", 'estudis', 'per', 'definir'] les
# ['denunciada', 'per', '23', 'empreses'] que
# ['a', 'fer', 'un', 'estudi'] de
# ['Ha', 'estat', 'una', 'victòria'] "
# [',', 'ja_que', 'li', 'provoca'] una
# ['de', 'la', 'Generalitat', '</s>'] <s>
# ['mentalització', 'i', 'el', 'dibuix'] d'
# ['de', 'primera', 'divisió', 'Kosovo'] i
# ['i', 'Rascagneres', 'és', 'de'] 16
# ['atropellat', 'i', 'matat', 'dos'] treballadors
# ['recordat', 'que', 'les', 'peticions'] catalanes
# ['és', 'barat', '</s>', '<s>'] Accidentalment
# ['enfront_de', 'les', '0,852', 'unitats'] de
# ['la', 'comissió', 'José_María_Ruiz_de_la_Serna', '</s>'] <s>
# [',', '"', 'ens', 'reproduirem'] d'
# ['a', 'Roma', ',', 'és'] estrany
# ['basc', 'per', 'la', '"'] condescendència
# ['dels', 'participants', "s'", 'han'] presentat
# ['pessetes', '</s>', '<s>', "L'"] orquestra
# ['que', 'va', 'elaborar', 'la'] Constitució
# ['sistema', 'de', 'vot', 'per'] correu
# ['els', 'fàrmacs', ',', 'segons'] ha
# ['que', 'Erc', 'ja', 'no'] pot
# ['que', 'procedeixin', "'", '</s>'] <s>
# ['segons', 'van', 'denunciar', 'ahir'] els
# ['<s>', 'Precisament', ',', "l'"] increment
# ['</s>', '<s>', 'El', 'portaveu'] de
# ['presentada', 'ahir', 'al', 'ple'] ordinari
# ['processat', ',', 'Nsaar_Maati', ','] de
# ['de', 'les', 'institucions', ','] organització
# ['Dylan', 'durant', 'més', 'de'] 700
# [',', 'que', 'rebran', 'uns'] 2,5
# ['del', 'partit', 'a', 'França'] i
# ['<s>', '"', 'És', 'un'] local
# ['on', 'comparteix', 'estudis', 'i'] escenaris
# ['demana', "'", '</s>', '<s>'] Del_Pozo
# ['de', 'Pau_Gasol', '</s>', '<s>'] La
# ['Copaga', 'realitzava', '</s>', '<s>'] El
# ['al', 'reequilibri', 'territorial', "a_partir_d'"] iniciatives
# ['que', 'el', 'candidat', 'socialista'] surt
# ['gairebé', 'la', 'totalitat', 'de'] la
# ['superat', 'les', '2.000', 'persones'] </s>
# ['que', 'se', 'senten', 'de'] tot_arreu
# ['amb', 'certesa', 'pel', 'taxista'] ni
# ['<s>', 'Bankpyme', 'ha', 'estat'] històricament
# [',', 'Toni_Llassera', ',', 'Fredi_Puig'] ,
# ['uns', 'lavabos', 'públics', ','] ha
# ['la', 'fira', '</s>', '<s>'] La
# ['participació', 'massiva', 'als', 'comicis'] del
# ['països', '</s>', '<s>', 'La'] major
# ['</s>', '<s>', 'El', 'nucli'] inicial
# ['al', 'final', 'per', 'les'] ocasions
# ['conclusions', 'dels', 'debats', 'Osona_XXI'] i
# ['la', 'creació', 'de', "l'"] Estat
# ['és', 'una', 'oportunitat', 'per'] al
# ['cotitzades', 'en', 'activitats', 'relacionades'] amb
# ['del', 'Valladolid', 'és', "l'"] única
# [',', 'al', 'PSUC', 'i'] també
# [',', 'consensuades', 'amb', 'la'] ciutadania
# ['</s>', '<s>', 'Els', 'fets'] van
# ['la', 'celebració', 'del', '1_de_maig'] d'
# ['18%', 'de', 'botigues', 'més'] petites
# ['curs', 'també', "s'", 'impartiran'] al
# ['decoració', 'mural', 'pintada', 'a'] la
# [',', 'quan', "l'", 'Alabès'] pressionava
# ['</s>', '<s>', 'Les', 'víctimes'] ,
# ['estat', 'la', 'força', 'més'] votada
# ['incorporat', 'a', 'la', 'màquina'] a
# ['dels', 'anys_30', '</s>', '<s>'] Amb
# ['que', 'té', 'per', 'candidat'] al
# ['i', 'Reus', ',', 'que'] tindrà
# ['dit', 'de', 'la', 'mà'] ,
# ['i', 'ara', 'els', 'congressos'] ,
# ['el', 'Consell_General_del_Poder_Judicial', 'CGPJ', 'de'] tots
# ['va', 'apel·lar', 'contra', 'la'] sentència
# ['banda', 'va', 'començar', "'"] molt
# ["'", 'encara', 'ha', 'de'] demostrar
# ['convertir', 'la', 'no-violència', 'en'] la
# ['peu', 'de', 'vaixell', 'un'] punt
# ['mitjanes', 'empreses', 'són', '"'] el
# ['detingudes', 'per', 'la', 'policia'] ni
# ["'", '</s>', '<s>', "'"] Cal
# [',', 'a_càrrec_de', 'Carme_Riera', ','] Daniel_Gelabert
# ["d'", 'autor', ',', 'se'] 'n
# ['</s>', '<s>', 'El', 'cap'] de
# ['fet', 'biofísicament', 'pervers', ','] una
# ['trigat', 'un', 'any', 'a'] concedir
# ['fermes', 'amb', 'altres', 'músics'] com
# ['La', 'llista', 'de', 'noms'] que
# ['aquesta', 'comunitat', ',', 'especialment'] al
# ['mediambientals', '</s>', '<s>', 'Al'] Parc_Natural_del_Delta_de_l'_Ebre
# [',', "s'", 'estructura', 'en'] vuit
# ['pessetes', 'més', 'per', 'a'] infraestructures
# ['la_seva', 'innocència', '</s>', '<s>'] Des_de
# ['estudiada', 'podria', 'ser', 'perfectament'] la
# ['sense', 'que', 'Síria', ','] que
# ['capital', 'social', 'de', 'Filo'] ,
# ['li', 'va', 'comunicar', 'que'] hi
# ['en', 'substitució', 'de', 'Manel_Nadal'] que
# ['al·legacions', 'de', 'CiU', 'destaca'] la
# ['i', 'en', 'els', 'productes'] energètics
# ['presentar', 'un', 'projecte', 'més'] detallat
# ['Madrid', ',', 'València', ','] Sevilla
# ['</s>', '<s>', 'Es', 'tracta'] d'
# ['seva', '"', '</s>', '<s>'] El
# ['el', 'van', 'obligar', 'a'] conduir
# ['president', 'de', 'Caprabo', ','] conseller
# ['la', 'dels', 'treballadors', 'en'] una
# ['de', 'la', 'concessió', 'definitiva'] a
# ['quatre', 'de', 'femenines', '</s>'] <s>
# ['i', 'això', ',', "l'"] electorat
# ['dirigents', 'de', 'la', 'coalició'] han
# [',', 'i', 'els', 'processats'] són
# ['perquè', 'vostè', 'segurament', 'ja'] ho
# ['i', "l'", 'oportunisme', 'més'] descarnat
# ['una', 'pena', 'de', '4'] anys
# ['corredors', "d'", 'altres', 'infraestructures'] ja
# ['més', 'pressió', 'policial', '</s>'] <s>
# ['què', 'va', 'començar', 'la'] votació
# ['bany', 'complet', ',', 'una'] cuina
# ['ha', 'demostrat', 'en', 'el'] passat
# ['En_canvi', ',', 'el', 'pitjor'] comportament
# ['dels', 'rendiments', ',', 'especialment'] a
# [',', 'demana', 'a', "l'"] Ajuntament_de_Manresa
# ['És', 'el', 'color', 'del'] desacord
# ['quals', 'se', 'situarà', 'entre'] 10,12
# ['estudi', 'més', 'aprofundit', 'de'] l'
# ['<s>', '"', 'No', 'li'] hem
# ['dos', 'van', 'acordar', 'aprofundir'] la
# ['qüestió', 'que', 'ja', 'va'] aixecar
# ['ratifiquen', 'la_nostra', 'línia', 'ascendent'] '
# ['139', 'pessetes', 'mentre_que', 'el'] període
# ['recerca', 'en', 'els', 'estudis'] preuniversitaris
# ['devia', 'tenir', 'alguna', 'música'] al
# ['de', 'Daewoo', 'en', 'accions'] preferents
# ['dóna', 'dues', 'respostes', 'post_mortem'] </s>
# ['i', 'vuit', 'grans', 'sitges'] medievals
# ["L'", 'Ajuntament_de_Salt', 'ha', 'elaborat'] un
# ['virus', 'no', 'es', 'replica'] durant
# ['la', 'situació', 'política', 'al'] País_Basc
# ['amenaces', 'contra', 'la_seva', 'filla'] ,
# [',', 'en', 'què', 'participen'] nou
# ['les', 'autòpsies', 'podran', 'determinar'] si
# ['vol', 'posar', 'a', "l'"] abast
# ["l'", 'empresa', 'Cespa_GR', '</s>'] <s>
# ['de', 'la', 'C-1412', '1.685'] milions
# ['governs', "d'", 'esquerres', 'però'] des_de
# ['paternalistes', "d'", 'algunes', 'administracions'] i
# ['mai', 'amb', 'despotisme', '"'] ,
# ['una', 'altra', 'a', "l'"] Empordà
# ['esforç', 'suplementari', 'de', 'documentació'] històrica
# ['arriben', 'diverses', '</s>', '<s>'] Zinedine_Zidane
# ['de', 'violins', 'del', 'món'] es
# [',', 'també', "s'", 'hi'] ha
# ['el', "'", 'testimoni', 'vital'] lliurat
# ['</s>', '<s>', 'El', 'petó'] d'
# ['regidora', 'del', 'districte', ','] Imma_Moraleda
# ['</s>', '<s>', 'I', 'això'] és
# ['els', 'primers', 'mesos', 'de'] gestació
# ['a', "l'", 'interior', "d'"] un
# ['Suwon', ',', 'Inchon', ','] Jeonju
# ['</s>', '<s>', '-', 'He'] llegit
# ['27_de_desembre', ',', 'i', "l'"] òpera
# ['de', 'goril·la', 'i', 'de'] gàngster
# ['Catalunya', '"', '</s>', '<s>'] Ara
# ['assemblea', "d'", 'okupes', ','] ha
# ["'", 'una', 'maniobra', 'política'] per
# ['any', 'que', 've', '</s>'] <s>
# ['presentat', 'una', 'proposició', 'de'] llei
# ['amb', 'cura', 'per', 'conservar'] les
# ['es', 'va', 'perllongar', 'per'] uns
# ['edificis', 'de', 'nova', 'planta'] d'
# ['tancar', 'ahir', 'amb', 'descensos'] moderats
# ['durà', 'botes', 'ranxeres', 'als'] actes
# ['</s>', '<s>', 'El', 'portaveu'] d'
# ['que', 'permet', 'travessar', 'el'] Fluvià
# ['ciutadans', 'del', 'carrer', ','] que
# ['i', 'mítings', 'sobre', 'Gibraltar'] entre
# ['<s>', 'Fuster', 'considera', 'que'] el
# ['soterrada', '</s>', '<s>', 'Al_mateix_temps'] ,
# ['caldrà', 'consultar', 'els', 'mateixos'] premis
# ['que', 'la', 'primera', 'idea'] del
# ['de', 'la', 'Corona', 'si'] es
# ['fotografia', 'va', 'presentar', 'dijous'] a
# ['agrupa', 'el', 'col·lectiu', 'de'] minusvàlids
# ['membres', 'del', 'govern', 'de'] l'
# ['</s>', '<s>', 'Idoia_Zenarruzabeitia', ','] fins
# ['nou_del_vespre', '</s>', '<s>', 'A'] la
# ['correspondria', 'segons', 'la_seva', 'riquesa'] </s>
# ['per', 'analitzar', 'els', 'efectes'] de
# ['amb', 'Luján', 'i', 'Vilanova'] ,
# ['retards', 'que', 'poden', 'batre'] rècords
# [',', 'detingut', 'el', 'dia_25'] passat
# ["d'", 'habitants', 'que', 'Alemanya'] i
# ['llistes', "d'", 'espera', 'i'] s'
# ['de', 'Cultura', ',', 'Pilar_del_Castillo'] ,
# ['nucli', 'inicial', 'de', 'la'] plataforma
# ['que', 'va', 'funcionar', 'abans'] dels
# ['Es', 'va', 'produir', 'quan'] dos
# ['Carod', 'ha', 'acusat', 'Pujol'] de
# ['fer', 'compres', 'per', 'valor'] de
# ['que', 'no', 'troba', 'els'] ressorts
# ['que', 'es', 'va', 'aconseguir'] ara
# ['dels', 'països', 'de', "l'"] Est
# ['aquests', 'mesos', "'", 'no'] s'
# ['setmana', 'sense', 'que', 'ni'] el
# ['el', 'Premi_Hammet_1989', '-', 'concedit'] per
# ['per', 'prevaricació', 'en', 'la_seva'] actuació
# ['a', "l'", 'altura', 'de'] Figueres
# ['Museu_Comarcal', ',', 'una', 'obra'] que
# ['2', 'plànols', 'originals', 'de'] l'
# ['va', 'entrar', 'com_a', 'capellà'] a
# ['<s>', 'Després', 'va', 'deixar'] -la
# ['la', 'Diada', '</s>', '<s>'] Il_Baluardo_de_Lucca
# ['i', 'Llobregat', '</s>', '<s>'] La
# ['de', 'teatre', ',', 'música'] i
# [',', 'que', 'aleshores', 'tenia'] 24
# ['en_privat', 'que', 'el', 'secretari'] d'
# [',', '107', 'van', 'ser'] préstecs
# ['està', 'al', 'límit', 'del'] vulgar
# ['convidat', 'a', 'tornar', 'a'] Kosovo
# ['han', 'col·locat', "l'", 'advocat'] Eugeni_Gay
# ['siguin', 'restituïts', 'a', 'Catalunya'] ja_que
# ['i', 'valorar', 'els', 'actuals'] projectes
# ['mantenir', '-lo', 'així', ','] s'
# ['</s>', '<s>', '"', 'Només'] es
# ['<s>', 'La', 'crisi', 'dels'] mercats
# ['els', 'va', 'permetre', 'assegurar'] -se
# ['constants', 'vitals', 'del', 'nen'] continuen
# ['per', 'persona', 'de', '51.200'] PTA
# ['temes', 'que', 'realment', 'els'] afectin
# ['a_càrrec_de', 'la', 'companyia', "'"] El_vestidor
# ['de', 'Maria_Cristina', '</s>', '<s>'] Concerts
# ['citades', 'targes', 'i', 'descarregar'] els
# ['variava', 'la', 'forma', 'del'] llit
# ['quan', 'des_del', 'Govern', 'es'] reclama
# ["d'", 'euros', 'més', 'de'] 102.993
# ['membres', 'de', 'la', 'Policía_Nacional'] que
# ['Espanya', 'de', 'forma', 'il·legal'] </s>
# ['és', 'promoure', "l'", 'intercanvi'] cultural
# ['catalana', 'i', 'brasilera', ','] i
# ['el', 'Departament_de_Medi_Ambient', 'té', 'com_a'] un
# ['parer', ',', 'no', 'confondre'] el
# ['està', 'disposada', 'a', 'resoldre'] amb
# ['de', 'cessació', 'tabàquica', "d'"] àmbit
# ['en', 'que', 'hi', 'ha'] més
# ['crescut', 'respecte', "l'", 'any_2002'] ,
# ['</s>', '<s>', 'Segons', 'el'] candidat
# ['al', 'Mar_Menor', 'i', 'el'] Novelda
# ['han', 'tramès', 'els', 'ajuntaments'] </s>
# ['les', 'protestes', 'pel', 'cas'] de
# ['<s>', 'Tots', 'els', 'components'] procedeixen
# ['si', 'els', 'arriba', ','] i
# ['una', 'delegació', 'de', 'la'] companyia
# ['Inferix', ',', 'en', 'què'] escriuen
# ['el', 'ministre', 'de', 'Foment'] ,
# ['ajuntament', 'i', 'en', 'tot'] cas
# ['història', 'de', 'la', 'Congregació'] besaluenca
# ['passat', '591', 'milions', "d'"] euros
# ['el_seu', 'suport', 'i', 'confiança'] </s>
# ['tenen', 'alguns', 'dirigents', 'polítics'] per
# ['al', 'Congrés', 'i', 'al'] Senat
# ['i', 'Amèrica', '</s>', '<s>'] Marc_Parrot
# ['intoxicació', 'per', 'consum', 'de'] drogues
# ['pintar', 'els_seus', 'murals', '</s>'] <s>
# ['que', ',', 'independentment', 'del'] lloc
# ['-', 'no', 'és', 'només'] estètic
# ['els', 'agents', "'", 'se'] li
# ['venjança', 'a', "l'", 'hora'] del
# ['el', 'municipalisme', 'de', 'Catalunya'] "
# ['milions', ',', 'la', 'construcció'] de
# ['dels', 'dos', 'concerts', 'celebrats'] ,
# ['pacte', 'de', 'govern', 'amb'] Convergènia_i_Unió
# ['mateixes', 'que', "l'", 'any'] passat
# [',', 'a_més_a_més', 'del', 'triomf'] del
# ['estat', 'tramitats', '</s>', '<s>'] Després
# ['web', 'de', 'serveis', 'que'] es
# ['afegir', 'que', '"', 'Mèxic'] ja
# ['"', 'massacres', '"', 'israelianes'] ,
# ['en', 'carretera', ',', 'com_ara'] educar
# ['registra', 'per', 'la', 'reducció'] horària
# ['del', 'Besòs', ',', 'on'] l'
# ['colors', 'en', 'la', 'unitat'] del
# ['beneficiats', 'per', 'aquest', 'conflicte'] ,
# ['dels', 'juvenils', '</s>', '<s>'] Però
# ['nova', 'possibilitat', ',', 'però'] es
# ['CiU', 'i', 'PP', 'van'] fer
# ['de', 'Genesis', ',', 'King_Crimson'] i
# ['ha', 'posat_de_manifest', 'el_seu', 'interès'] en
# ['rapinyaire', 'símbol', 'de', 'la'] reserva
# ['dos', 'personatges', 'corrien', 'i'] saltaven
# ['Ajuntament_de_Barcelona', ',', 'així_com', 'de'] més
# ['per', 'altres', 'quantitats', 'pendents'] </s>
# ['</s>', '<s>', 'En', 'el'] mateix
# ["d'", 'aquí', 'uns', 'anys'] hi
# ['Sóc', 'conscient', 'que', 'estic'] al_capdavant
# ['barri', 'de', 'Llefià', ','] en_gran_mesura
# ['Regió_Metropolitana', 'preferirien', "l'", 'estació'] del
# ['qualsevol', 'persona', 'del', 'carrer'] ,
# ['crit', 'al', 'cel', 'per'] aquesta
# ['entre', 'els', 'demandants', 'i'] el
# ['un', 'centre', 'psiquiàtric', ','] ha
# ['la', 'comarca', 'del', 'Baix_Camp'] va
# ['fet', 'a', 'institucions', 'com'] la

# %%
class NNLM(nn.Module):
    def __init__(self, num_classes, dim_input, dim_hidden, dim_embedding):
        super(NNLM, self).__init__()
        self.num_classes = num_classes
        self.dim_input = dim_input
        self.dim_hidden = dim_hidden
        self.dim_embedding = dim_embedding
        self.embeddings = nn.Embedding(self.num_classes, self.dim_embedding) # embedding layer or look up table
        self.hidden1 = nn.Linear(self.dim_input * self.dim_embedding, self.dim_hidden, bias=False)
        self.ones = nn.Parameter(torch.ones(self.dim_hidden))       
        self.hidden2 = nn.Linear(self.dim_hidden, self.num_classes, bias=False)
        self.hidden3 = nn.Linear(self.dim_input * self.dim_embedding, self.num_classes, bias=False) # final layer
        self.bias = nn.Parameter(torch.ones(self.num_classes))

    def forward(self, X):
        word_embeds = self.embeddings(X)
        X = word_embeds.view(-1, self.dim_input * self.dim_embedding) # first layer
        tanh = torch.tanh(self.ones + self.hidden1(X)) # tanh layer
        output = self.bias + self.hidden3(X) + self.hidden2(tanh) # summing up all the layers with bias
        return output


num_classes = dataset.vocabulary_size
dim_input = length_window - 1
dim_hidden = 50
dim_embedding = 32
learning_rate= 1e-3
num_epochs = 60

model = NNLM(num_classes, dim_input, dim_hidden, dim_embedding)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

path = 'NNLM.pt'
do_train = True
do_test = True

# %%
# In the top menu go to Runtime -> Change runtime type and set Hardware 
# accelerator to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
model = model.to(device)
# Out:
# cuda:0

# %%
from torch.cuda.random import device_count
if do_train:
    size = len(dataloader.dataset)
    for epoch in range(num_epochs):
        for batch, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if batch % 100 == 0:
                loss, current = loss.item(), batch * batch_size
                print('Epoch {} loss: {:>7f}  [{:>5d}/{:>5d}]'
                    .format(epoch+1, loss, current, size))

    torch.save({'model_state_dict': model.state_dict()}, path)
else:
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# Epoch 1 loss: 10.863346  [    0/509115]
# Epoch 1 loss: 7.100326  [100000/509115]
# Epoch 1 loss: 6.709040  [200000/509115]
# Epoch 1 loss: 6.421080  [300000/509115]
# Epoch 1 loss: 6.210479  [400000/509115]
# Epoch 1 loss: 6.266020  [500000/509115]
# Epoch 2 loss: 5.700747  [    0/509115]
# Epoch 2 loss: 5.724219  [100000/509115]
# Epoch 2 loss: 5.642992  [200000/509115]
# Epoch 2 loss: 5.635747  [300000/509115]
# Epoch 2 loss: 5.818430  [400000/509115]
# Epoch 2 loss: 5.393681  [500000/509115]
# Epoch 3 loss: 5.005529  [    0/509115]
# Epoch 3 loss: 5.022326  [100000/509115]
# Epoch 3 loss: 5.185536  [200000/509115]
# Epoch 3 loss: 5.042937  [300000/509115]
# Epoch 3 loss: 5.038917  [400000/509115]
# Epoch 55 loss: 2.234220  [200000/509115]
# Epoch 55 loss: 2.262312  [300000/509115]
# Epoch 55 loss: 2.255466  [400000/509115]
# Epoch 55 loss: 2.202634  [500000/509115]
# Epoch 56 loss: 1.995180  [    0/509115]
# Epoch 56 loss: 2.110947  [100000/509115]
# Epoch 56 loss: 2.142670  [200000/509115]
# Epoch 56 loss: 2.184431  [300000/509115]
# Epoch 56 loss: 2.191448  [400000/509115]
# Epoch 56 loss: 2.143110  [500000/509115]
# Epoch 57 loss: 2.059707  [    0/509115]
# Epoch 57 loss: 2.119590  [100000/509115]
# Epoch 57 loss: 2.129491  [200000/509115]
# Epoch 57 loss: 2.182806  [300000/509115]
# Epoch 57 loss: 2.140287  [400000/509115]
# Epoch 57 loss: 2.262031  [500000/509115]
# Epoch 58 loss: 2.076793  [    0/509115]
# Epoch 58 loss: 2.126055  [100000/509115]
# Epoch 58 loss: 2.127496  [200000/509115]
# Epoch 58 loss: 2.208851  [300000/509115]
# Epoch 58 loss: 2.194159  [400000/509115]
# Epoch 58 loss: 2.268237  [500000/509115]
# Epoch 59 loss: 2.118849  [    0/509115]
# Epoch 59 loss: 2.066362  [100000/509115]
# Epoch 59 loss: 2.100207  [200000/509115]
# Epoch 59 loss: 2.148565  [300000/509115]
# Epoch 59 loss: 2.267311  [400000/509115]
# Epoch 59 loss: 2.155003  [500000/509115]
# Epoch 60 loss: 1.967318  [    0/509115]
# Epoch 60 loss: 1.938570  [100000/509115]
# Epoch 60 loss: 2.103725  [200000/509115]
# Epoch 60 loss: 2.072762  [300000/509115]
# Epoch 60 loss: 2.172828  [400000/509115]
# Epoch 60 loss: 2.120824  [500000/509115]

# %%
if do_test:
    num_sentences = 5
    max_num_words = 100

    nsent = 0
    generated_words = ['<s>', 'El', 'dia', 'que']
    assert len(generated_words)==dim_input # length_window-1

    model.eval()
    with torch.no_grad():
        while (nsent < num_sentences) and (len(generated_words) < max_num_words):
            input_ids = [dataset.word2id[w] for w in generated_words[-dim_input:]]
            pred = model(torch.tensor(input_ids).unsqueeze(0).to(device))
            
            #output_id = torch.argmax(pred)

            probs = torch.nn.functional.softmax(pred, dim=1)
            output_id = torch.multinomial(probs,1)
            output_word = dataset.id2word[output_id.item()]
            generated_words += [output_word]
            if output_word=='</s>':
                nsent += 1

    generated_text = ' '.join(generated_words)
    generated_text = generated_text.replace(' </s> <s>', '.').replace('<s> ','').replace(' </s>','.')
    for s in [' l\' ',' s\' ',' d\' ',]:
        generated_text = generated_text.replace(s, s[:-1])
    generated_text = generated_text.replace(' , ', ', ').replace('_',' ')
    print(generated_text)
# Out:
# El dia que cada dia se porta el judici per facilitar la participació ", va declarar ahir en l'extinció sinó que es va fer fugir del cotxe el 99. ETA qüestions continua entrevistes a l'antic principal indemnització que jo podem defensar tot la seva obra, ell ha reconegut que amb el CPC " compartim la seva voluntat de dialogar amb els futbolistes. Aquests Lleida, que s'aniran convocant alternativament a l'art de Catalunya, com ara la que presentava esforç en horari del cementiri dels conductors - : " La dirigir es basa
